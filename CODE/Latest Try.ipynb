# %%
# import modules
import pandas as pd

# load data files
contacts_pre_2017=pd.read_csv('Contacts_Pre_2017.csv')
resolution_pre_2017=pd.read_csv('Resolution_Pre_2017.csv', encoding='iso8859-1')

contacts2017=pd.read_csv('Contacts2017.csv')
resolution2017=pd.read_csv('Resolution2017.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.ensemble import VotingClassifier
from sklearn.externals import joblib
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import log_loss

# %%
pd.DataFrame({'Contacts' : contacts_pre_2017.groupby(['CONTACT.TYPE'] )['Contacts'].count()}).reset_index()
# Out:
#                   CONTACT.TYPE  Contacts
# 0                 Call - Input      3092
# 1                  Fax - Input      1839
# 2  Fax Acknowledgement - Input      1760
# 3  Installation Report - Input       206
# 4          Internal Management      2333
# 5                 Mail - Input      1624
# 6              Mail - Recieved      2079
# 7                Tweet - Input        73
# 8                        Visit      1744
# 9                  Web - Input      2562

# %%
CI = contacts_pre_2017.loc[contacts_pre_2017['CONTACT.TYPE'] == 'Call - Input']
FI = contacts_pre_2017.loc[contacts_pre_2017['CONTACT.TYPE'] == 'Fax - Input']
FAI = contacts_pre_2017.loc[contacts_pre_2017['CONTACT.TYPE'] == 'Fax Acknowledgement - Input']
IR = contacts_pre_2017.loc[contacts_pre_2017['CONTACT.TYPE'] == 'Installation Report - Input']
IM = contacts_pre_2017.loc[contacts_pre_2017['CONTACT.TYPE'] == 'Internal Management']
MI = contacts_pre_2017.loc[contacts_pre_2017['CONTACT.TYPE'] == 'Mail - Input']
MR = contacts_pre_2017.loc[contacts_pre_2017['CONTACT.TYPE'] == 'Mail - Recieved']
TI = contacts_pre_2017.loc[contacts_pre_2017['CONTACT.TYPE'] == 'Tweet - Input']
WI = contacts_pre_2017.loc[contacts_pre_2017['CONTACT.TYPE'] == 'Web - Input']

# %%
CI.plot()
FI.plot()
FAI.plot()
IR.plot()
IM.plot()
MI.plot()
MR.plot()
TI.plot()
WI.plot()
plt.show()

# %%
CI.to_csv("CI.csv",index=False)
FI.to_csv("FI.csv",index=False)
FAI.to_csv("FAI.csv",index=False)
IR.to_csv("IR.csv",index=False)
IM.to_csv("IM.csv",index=False)
MI.to_csv("MI.csv",index=False)
MR.to_csv("MR.csv",index=False)
TI.to_csv("TI.csv",index=False)
WI.to_csv("WI.csv",index=False)
